# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

url = "https://www.dogilike.com/breeds/1/"  #<----- input URL web

req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})

page = urlopen(req)
soup = BeautifulSoup(page)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <title>เกรทเดน (Great Dane) | Dogilike.com</title>
# <meta content="ข้อมูลสายพันธุ์อย่างละเอียด ลักษณะ นิสัย และภาพพันธุ์สุนัข - น้องหมาตัวใหญ่ใจดี ขี้ประจบ แถมยังฉลาดเป็นกรดอีกต่างหาก..." name="description"/>
# <meta content="เกรทเดน, Great Dane, สุนัขพันธุ์เกรทเดน, หมาพันธุ์เกรทเดน, พันธุ์เกรทเดน, เกรตเดน, พันธุ์หมา, สุนัขพันธุ์, พันธุ์สุนัข" name="keywords"/>
# <meta content="aUmlS7YMy1dP97G4FhkV_ZSCO9MnVT3PmqzEHGkb2PM" name="google-site-verification"/>
# <meta content="เกรทเดน (Great Dane) | Dogilike.com" property="og:title"/>
# <meta content="https://www.dogilike.com/" property="og:url"/>
# <meta content="https://image.dogilike.com/shareimg/dogthumb_breed/1" property="og:image"/>
# <meta content="Dogilike.com" property="og:site_name"/>
# ...

# %%
 # ทำให้ข้อมูลเป็นระเบียบ ดูง่าย ด้วยคำสั่ง prettify()
 print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="th">
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <title>
#    เกรทเดน (Great Dane) | Dogilike.com
#   </title>
#   <meta content="ข้อมูลสายพันธุ์อย่างละเอียด ลักษณะ นิสัย และภาพพันธุ์สุนัข - น้องหมาตัวใหญ่ใจดี ขี้ประจบ แถมยังฉลาดเป็นกรดอีกต่างหาก..." name="description"/>
#   <meta content="เกรทเดน, Great Dane, สุนัขพันธุ์เกรทเดน, หมาพันธุ์เกรทเดน, พันธุ์เกรทเดน, เกรตเดน, พันธุ์หมา, สุนัขพันธุ์, พันธุ์สุนัข" name="keywords"/>
#   <meta content="aUmlS7YMy1dP97G4FhkV_ZSCO9MnVT3PmqzEHGkb2PM" name="google-site-verification"/>
#   <meta content="เกรทเดน (Great Dane) | Dogilike.com" property="og:title"/>
#   <meta content="https://www.dogilike.com/" property="og:url"/>
#   <meta content="https://image.dogilike.com/shareimg/dogthumb_breed/1" property="og:image"/>
#   <meta content="Dogilike.com" property="og:site_name"/>
# ...

# %%
breedname = soup.findAll("h1")
len(breedname)
# Out:
# 8

# %%
name = [];
for i in breedname:
    print(i)
    name.append(i)
# Out:
# เจแปนีส ชิน

# %%
pic = soup.findAll('img')
pic
# Out:
# [<img alt="Dog Image, รูปหมาโกลเด้น" class="rc-image-menu-item rc-md-up" src="https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=320&amp; 320w,https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=360&amp; 360w,https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=640&amp; 640w,https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=720&amp; 720w,https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=960&amp; 960w,https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=1280&amp; 1280w,https://cdn.royalcanin-weshare-online.io/QucC238BaPOZra8qTdaN/v3/topnav-dog?w=1440&amp; 1440w"/>,
# ...

# %%
len(pic)
# Out:
# 7

# %%
pic[6]
# Out:
# <img alt="Japanese Chin adult black and white" class="lazyload" data-sizes="auto" data-srcset="https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=320&amp; 320w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=360&amp; 360w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=640&amp; 640w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=720&amp; 720w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=960&amp; 960w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=1280&amp; 1280w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=1440&amp; 1440w" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3
# ...

# %%
pic[6]['alt']
# Out:
# 'Japanese Chin adult black and white'

# %%
pic[6]['data-srcset']
# Out:
# 'https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=320& 320w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=360& 360w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=640& 640w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=720& 720w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=960& 960w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=1280& 1280w,https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=1440& 1440w'

# %%
urlpic = 'https://cdn.royalcanin-weshare-online.io/Lfopx2oBIYfdNSoCBRkq/v1/bd79h-hub-japanese-chin-black-and-white?w=320& 320w'

# %%
from PIL import Image
import io

# %%
r1=requests.get(urlpic)
img=Image.open(io.BytesIO(r1.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x240>

# %%
about = soup.findAll('h2')
about[0]
# Out:
# <h2 class="rc-beta">เกี่ยวกับสายพันธุ์เจแปนีส ชิน</h2>

# %%
about_info = soup.findAll('p')
about_info
# Out:
# [<p class="rc-meta">บริการอื่นๆ ของโรยัล คานิน</p>,
#  <p class="rc-meta">
#  โภชนาการที่เหมาะสำหรับสุนัขทุกวัย ทุกขนาด และทุกสายพันธุ์
#  </p>,
#  <p class="rc-meta">
#  ช่วยดูแลสุนัขที่มีปัญหาสุขภาพ
#  </p>,
#  <p class="rc-meta">
#  โภชนาการที่เหมาะสำหรับแมวทุกวัย ทุกขนาด และทุกสายพันธุ์
#  </p>,
#  <p class="rc-meta">
#  ช่วยดูแลแมวที่มีปัญหาสุขภาพ
#  </p>,
#  <p class="rc-delta">หากคุณมีคำถาม</p>,
#  <p class="body-copy">หรือต้องการความช่วยเหลือ สามารถติดต่อเราได้ที่</p>,
#  <p>[เวลาเปิดทำการ]</p>,
#  <p>เจแปนีส ชินเป็นสุนัขสายพันธุ์หนึ่งที่มีความตื่นตัว อ่อนโยน และน่ารัก เป็นเพื่อนสี่ขาที่ยอดเยี่ยม ลักษณะนิสัยที่อยากรู้อยากเห็นและฉลาดของเจ้าสี่ขาเหล่านี้สะท้อนให้เห็นได้ในสีหน้าท่าทางของพวกเขา </p>,
#  <p>สุนัขสายพันธุ์เจแปนีส ชินขึ้นชื่อว่าเป็นสุนัขที่เป็นที่รักและสง่างาม สุนัขสายพันธุ์นี้ขี้อ้อนกับเจ้าของ ไม่มีอะไรที่เจแปนีส ชินจะชอบมากไปกว่าการได้อยู่ใกล้ชิดคลอเคลียเจ้าของ</p>,
# ...
